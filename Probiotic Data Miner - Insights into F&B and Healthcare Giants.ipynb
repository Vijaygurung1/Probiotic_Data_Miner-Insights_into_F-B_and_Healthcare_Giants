# %% [markdown]
# # Probiotic Data Miner: Insights into F&B and Healthcare Giants -
#
# # [ Company_DeepThought ]

# %% [markdown]
# - This project demonstrates web scraping and analysis of company websites to extract valuable insights into the probiotics market.
#
# - The goal is to identify trends, collaborations and innovations across F&B, pharmaceutical and healthcare companies.

# %%
#  **Project Overview**

#  **Objective** :
    
# To analyze data from company websites to uncover:

- Product offerings related to probiotics.
- Company profiles, partnerships, and collaborations.
- Research innovations and marketing efforts in the health segments.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Function to scrape website data

# %%
def scrape_website(url, company_name):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract general information
        title = soup.title.string if soup.title else "No Title"
        content = soup.get_text().lower()

        # Keywords for analysis
        product_keywords = ['product', 'ingredients', 'supplement', 'probiotic', 'fortification']
        profile_keywords = ['about us', 'vision', 'mission', 'history']
        partnership_keywords = ['partner', 'collaboration', 'supplier', 'distributor']
        research_keywords = ['research', 'study', 'innovation', 'patent', 'scientific']
        marketing_keywords = ['campaign', 'testimonial', 'customer', 'social media']
        
        # Information extraction
        product_info = any(keyword in content for keyword in product_keywords)
        company_profile = any(keyword in content for keyword in profile_keywords)
        partnerships = any(keyword in content for keyword in partnership_keywords)
        research_innovations = any(keyword in content for keyword in research_keywords)
        marketing_promotions = any(keyword in content for keyword in marketing_keywords)

        # Categorization
        category = 'Relevant' if product_info or company_profile else 'Not Relevant'
        
        return {
            'Company': company_name,
            'Website': url,
            'Title': title,
            'Category': category,
            'Product Info': "Yes" if product_info else "No",
            'Company Profile': "Yes" if company_profile else "No",
            'Partnerships': "Yes" if partnerships else "No",
            'Research & Innovations': "Yes" if research_innovations else "No",
            'Marketing & Promotions': "Yes" if marketing_promotions else "No"
        }
    except Exception as e:
        return {'Company': company_name, 'Website': url, 'Error': str(e)}

# %% [markdown]
# # List of companies and their websites

# %%
companies = [
    {"name": "Nestle", "website": "https://www.nestle.com"},
    {"name": "Dr. Reddy's Laboratories", "website": "https://www.drreddys.com"},
    {"name": "Coca-Cola", "website": "https://www.coca-colacompany.com"},
    {"name": "Pfizer", "website": "https://www.pfizer.com"},
    {"name": "PepsiCo", "website": "https://www.pepsico.com"},
    {"name": "Johnson & Johnson", "website": "https://www.jnj.com"},
    {"name": "Danone", "website": "https://www.danone.com"},
    {"name": "Bayer", "website": "https://www.bayer.com"},
    {"name": "General Mills", "website": "https://www.generalmills.com"},
    {"name": "GlaxoSmithKline (GSK)", "website": "https://www.gsk.com"},
    {"name": "Kellogg’s", "website": "https://www.kelloggs.com/en_US/home.html"},
    {"name": "Merck & Co.", "website": "https://www.merck.com"},
    {"name": "Unilever", "website": "https://www.unilever.com"},
    {"name": "Roche", "website": "https://www.roche.com"},
    {"name": "Nestle Waters", "website": "https://www.nestlewaters.com"},
    {"name": "Sanofi", "website": "https://www.sanofi.com"},
    {"name": "Mondelez International", "website": "https://www.mondelezinternational.com"},
    {"name": "Novartis", "website": "https://www.novartis.com"},
    {"name": "Kraft Heinz", "website": "https://www.kraftheinzcompany.com"},
    {"name": "Eli Lilly and Company", "website": "https://www.lilly.com"},
    {"name": "Tyson Foods", "website": "https://www.tysonfoods.com"},
    {"name": "Teva Pharmaceuticals", "website": "https://www.tevapharm.com"},
    {"name": "Mars, Incorporated", "website": "https://www.mars.com"},
    {"name": "AbbVie", "website": "https://www.abbvie.com"},
    {"name": "Campbell Soup Company", "website": "https://www.campbellsoupcompany.com"},
    {"name": "Amgen", "website": "https://www.amgen.com"},
    {"name": "Conagra Brands", "website": "https://www.conagrabrands.com"},
    {"name": "AstraZeneca", "website": "https://www.astrazeneca.com"},
    {"name": "Molson Coors", "website": "https://www.molsoncoors.com"},
    {"name": "Boehringer Ingelheim", "website": "https://www.boehringer-ingelheim.com"},
    {"name": "AB InBev", "website": "https://www.abinbev.com"},
    {"name": "BASF", "website": "https://www.basf.com"},
    {"name": "Diageo", "website": "https://www.diageo.com"},
    {"name": "Procter & Gamble (P&G)", "website": "https://www.pg.com"},
    {"name": "Heineken", "website": "https://www.theheinekencompany.com"},
    {"name": "Medtronic", "website": "https://www.medtronic.com"},
    {"name": "McKesson",  "website": "https://www.mckesson.com"},
    {"name":"AmerisourceBergen","website": "https://www.amerisourcebergen.com"}, 
    {"name":"Cardinal Health","website": "https://www.cardinalhealth.com/en.html"}, 
    {"name":"Medline Industries","website": "https://www.medline.com"} 
]

# %% [markdown]
# # Scrape data for each company

# %%
scraped_data = [scrape_website(company['website'], company['name']) for company in companies]

# %%
pd.DataFrame(scraped_data)
# Out:
#                      Company                                   Website  \
# 0                     Nestle                    https://www.nestle.com
# 1   Dr. Reddy's Laboratories                  https://www.drreddys.com
# 2                  Coca-Cola          https://www.coca-colacompany.com
# 3                     Pfizer                    https://www.pfizer.com
# 4                    PepsiCo                   https://www.pepsico.com
# 5          Johnson & Johnson                       https://www.jnj.com
# 6                     Danone                    https://www.danone.com
# 7                      Bayer                     https://www.bayer.com
# 8              General Mills              https://www.generalmills.com
# 9      GlaxoSmithKline (GSK)                       https://www.gsk.com
# 10                 Kellogg’s  https://www.kelloggs.com/en_US/home.html
# 11               Merck & Co.                     https://www.merck.com
# 12                  Unilever                  https://www.unilever.com
# 13                     Roche                     https://www.roche.com
# 14             Nestle Waters              https://www.nestlewaters.com
# 15                    Sanofi                    https://www.sanofi.com
# 16    Mondelez International     https://www.mondelezinternational.com
# 17                  Novartis                  https://www.novartis.com
# 18               Kraft Heinz         https://www.kraftheinzcompany.com
# 19     Eli Lilly and Company                     https://www.lilly.com
# 20               Tyson Foods                https://www.tysonfoods.com
# 21      Teva Pharmaceuticals                 https://www.tevapharm.com
# 22        Mars, Incorporated                      https://www.mars.com
# 23                    AbbVie                    https://www.abbvie.com
# 24     Campbell Soup Company       https://www.campbellsoupcompany.com
# 25                     Amgen                     https://www.amgen.com
# 26            Conagra Brands             https://www.conagrabrands.com
# 27               AstraZeneca               https://www.astrazeneca.com
# 28              Molson Coors               https://www.molsoncoors.com
# 29      Boehringer Ingelheim      https://www.boehringer-ingelheim.com
# 30                  AB InBev                   https://www.abinbev.com
# 31                      BASF                      https://www.basf.com
# 32                    Diageo                    https://www.diageo.com
# 33    Procter & Gamble (P&G)                        https://www.pg.com
# 34                  Heineken        https://www.theheinekencompany.com
# 35                 Medtronic                 https://www.medtronic.com
# 36                  McKesson                  https://www.mckesson.com
# 37         AmerisourceBergen         https://www.amerisourcebergen.com
# 38           Cardinal Health    https://www.cardinalhealth.com/en.html
# 39        Medline Industries                   https://www.medline.com
#
#                                                 Title      Category  \
# 0                                    Just a moment...  Not Relevant
# 1   Dr. Reddy’s Laboratories – Good Health Can’t Wait  Not Relevant
# 2   \n        The Coca-Cola Company: Refresh the W...      Relevant
# 3   Pfizer: One of the world's premier biopharmace...      Relevant
# 4                                            No Title  Not Relevant
# 5     Johnson & Johnson: Changing health for humanity      Relevant
# 6                        World food company - Danone       Relevant
# 7                                    Site Maintenance  Not Relevant
# 8   General Mills: A U.S. based food company. - Ge...      Relevant
# 9                                         Home | GSK       Relevant
# 10                                                NaN           NaN
# 11                                       Merck | Home      Relevant
# 12  Unilever Global: Making sustainable living com...      Relevant
# 13          Roche - Doing now what patients need next      Relevant
# 14                                   Just a moment...  Not Relevant
# 15   A Leading Immunology Healthcare Company | Sanofi      Relevant
# 16                Home | Mondelēz International, Inc.      Relevant
# 17                                           Novartis      Relevant
# 18                            The Kraft Heinz Company      Relevant
# 19                                   Just a moment...  Not Relevant
# 20                             Welcome To Tyson Foods      Relevant
# 21                                           No Title  Not Relevant
# 22  Global Petcare, Food & Nutrition, and Snacking...      Relevant
# 23                   Attention Required! | Cloudflare  Not Relevant
# 24                                      403 Forbidden  Not Relevant
# 25       Amgen | A Worldwide Pioneer in Biotechnology      Relevant
# 26                              Home | Conagra Brands      Relevant
# 27          ERROR: The request could not be satisfied  Not Relevant
# 28                                Home | Molson Coors      Relevant
# 29                                           No Title  Not Relevant
# 30                                    Home | AB InBev      Relevant
# 31                                       BASF – India      Relevant
# 32                   Attention Required! | Cloudflare  Not Relevant
# 33                                      403 Forbidden  Not Relevant
# 34                   Attention Required! | Cloudflare  Not Relevant
# 35                                   Home | Medtronic      Relevant
# 36  McKesson | Medical Supplies, Pharmaceuticals H...      Relevant
# 37  AmerisourceBergen | United in our responsibili...      Relevant
# 38                                                NaN           NaN
# 39             Medline.com | Medline Industries, Inc.      Relevant
#
#    Product Info Company Profile Partnerships Research & Innovations  \
# 0            No              No           No                     No
# 1            No              No           No                     No
# 2           Yes             Yes          Yes                    Yes
# 3           Yes             Yes          Yes                    Yes
# 4            No              No           No                     No
# 5           Yes             Yes          Yes                    Yes
# 6           Yes             Yes          Yes                    Yes
# 7            No              No           No                     No
# 8           Yes             Yes          Yes                     No
# 9           Yes             Yes          Yes                    Yes
# 10          NaN             NaN          NaN                    NaN
# 11          Yes             Yes          Yes                    Yes
# 12          Yes             Yes          Yes                    Yes
# 13          Yes             Yes          Yes                    Yes
# 14           No              No           No                     No
# 15          Yes             Yes          Yes                    Yes
# 16          Yes             Yes          Yes                    Yes
# 17          Yes             Yes          Yes                    Yes
# 18           No             Yes          Yes                     No
# 19           No              No           No                     No
# 20          Yes             Yes          Yes                    Yes
# 21           No              No           No                     No
# 22          Yes             Yes          Yes                    Yes
# 23           No              No           No                     No
# 24           No              No           No                     No
# 25          Yes             Yes          Yes                    Yes
# 26          Yes             Yes          Yes                    Yes
# 27           No              No           No                     No
# 28           No             Yes          Yes                     No
# 29           No              No           No                     No
# 30          Yes             Yes          Yes                    Yes
# 31          Yes              No           No                    Yes
# 32           No              No           No                     No
# 33           No              No           No                     No
# 34           No              No           No                     No
# 35          Yes             Yes          Yes                    Yes
# 36          Yes             Yes          Yes                    Yes
# 37          Yes             Yes          Yes                    Yes
# 38          NaN             NaN          NaN                    NaN
# 39          Yes              No           No                     No
#
#    Marketing & Promotions                                              Error
# 0                      No                                                NaN
# 1                      No                                                NaN
# 2                     Yes                                                NaN
# 3                      No                                                NaN
# 4                      No                                                NaN
# 5                     Yes                                                NaN
# 6                     Yes                                                NaN
# 7                      No                                                NaN
# 8                      No                                                NaN
# 9                     Yes                                                NaN
# 10                    NaN  HTTPSConnectionPool(host='www.kelloggs.com', p...
# 11                     No                                                NaN
# 12                     No                                                NaN
# 13                     No                                                NaN
# 14                     No                                                NaN
# 15                     No                                                NaN
# 16                     No                                                NaN
# 17                     No                                                NaN
# 18                     No                                                NaN
# 19                     No                                                NaN
# 20                    Yes                                                NaN
# 21                     No                                                NaN
# 22                    Yes                                                NaN
# 23                     No                                                NaN
# 24                     No                                                NaN
# 25                    Yes                                                NaN
# 26                    Yes                                                NaN
# 27                    Yes                                                NaN
# 28                     No                                                NaN
# 29                     No                                                NaN
# 30                     No                                                NaN
# 31                     No                                                NaN
# 32                     No                                                NaN
# 33                     No                                                NaN
# 34                     No                                                NaN
# 35                    Yes                                                NaN
# 36                    Yes                                                NaN
# 37                     No                                                NaN
# 38                    NaN  ('Connection aborted.', RemoteDisconnected('Re...
# 39                     No                                                NaN

# %% [markdown]
# # Saving results to a DataFrame (Df)

# %%
df = pd.DataFrame(scraped_data)

# %%
df
# Out:
#                      Company                                   Website  \
# 0                     Nestle                    https://www.nestle.com
# 1   Dr. Reddy's Laboratories                  https://www.drreddys.com
# 2                  Coca-Cola          https://www.coca-colacompany.com
# 3                     Pfizer                    https://www.pfizer.com
# 4                    PepsiCo                   https://www.pepsico.com
# 5          Johnson & Johnson                       https://www.jnj.com
# 6                     Danone                    https://www.danone.com
# 7                      Bayer                     https://www.bayer.com
# 8              General Mills              https://www.generalmills.com
# 9      GlaxoSmithKline (GSK)                       https://www.gsk.com
# 10                 Kellogg’s  https://www.kelloggs.com/en_US/home.html
# 11               Merck & Co.                     https://www.merck.com
# 12                  Unilever                  https://www.unilever.com
# 13                     Roche                     https://www.roche.com
# 14             Nestle Waters              https://www.nestlewaters.com
# 15                    Sanofi                    https://www.sanofi.com
# 16    Mondelez International     https://www.mondelezinternational.com
# 17                  Novartis                  https://www.novartis.com
# 18               Kraft Heinz         https://www.kraftheinzcompany.com
# 19     Eli Lilly and Company                     https://www.lilly.com
# 20               Tyson Foods                https://www.tysonfoods.com
# 21      Teva Pharmaceuticals                 https://www.tevapharm.com
# 22        Mars, Incorporated                      https://www.mars.com
# 23                    AbbVie                    https://www.abbvie.com
# 24     Campbell Soup Company       https://www.campbellsoupcompany.com
# 25                     Amgen                     https://www.amgen.com
# 26            Conagra Brands             https://www.conagrabrands.com
# 27               AstraZeneca               https://www.astrazeneca.com
# 28              Molson Coors               https://www.molsoncoors.com
# 29      Boehringer Ingelheim      https://www.boehringer-ingelheim.com
# 30                  AB InBev                   https://www.abinbev.com
# 31                      BASF                      https://www.basf.com
# 32                    Diageo                    https://www.diageo.com
# 33    Procter & Gamble (P&G)                        https://www.pg.com
# 34                  Heineken        https://www.theheinekencompany.com
# 35                 Medtronic                 https://www.medtronic.com
# 36                  McKesson                  https://www.mckesson.com
# 37         AmerisourceBergen         https://www.amerisourcebergen.com
# 38           Cardinal Health    https://www.cardinalhealth.com/en.html
# 39        Medline Industries                   https://www.medline.com
#
#                                                 Title      Category  \
# 0                                    Just a moment...  Not Relevant
# 1   Dr. Reddy’s Laboratories – Good Health Can’t Wait  Not Relevant
# 2   \n        The Coca-Cola Company: Refresh the W...      Relevant
# 3   Pfizer: One of the world's premier biopharmace...      Relevant
# 4                                            No Title  Not Relevant
# 5     Johnson & Johnson: Changing health for humanity      Relevant
# 6                        World food company - Danone       Relevant
# 7                                    Site Maintenance  Not Relevant
# 8   General Mills: A U.S. based food company. - Ge...      Relevant
# 9                                         Home | GSK       Relevant
# 10                                                NaN           NaN
# 11                                       Merck | Home      Relevant
# 12  Unilever Global: Making sustainable living com...      Relevant
# 13          Roche - Doing now what patients need next      Relevant
# 14                                   Just a moment...  Not Relevant
# 15   A Leading Immunology Healthcare Company | Sanofi      Relevant
# 16                Home | Mondelēz International, Inc.      Relevant
# 17                                           Novartis      Relevant
# 18                            The Kraft Heinz Company      Relevant
# 19                                   Just a moment...  Not Relevant
# 20                             Welcome To Tyson Foods      Relevant
# 21                                           No Title  Not Relevant
# 22  Global Petcare, Food & Nutrition, and Snacking...      Relevant
# 23                   Attention Required! | Cloudflare  Not Relevant
# 24                                      403 Forbidden  Not Relevant
# 25       Amgen | A Worldwide Pioneer in Biotechnology      Relevant
# 26                              Home | Conagra Brands      Relevant
# 27          ERROR: The request could not be satisfied  Not Relevant
# 28                                Home | Molson Coors      Relevant
# 29                                           No Title  Not Relevant
# 30                                    Home | AB InBev      Relevant
# 31                                       BASF – India      Relevant
# 32                   Attention Required! | Cloudflare  Not Relevant
# 33                                      403 Forbidden  Not Relevant
# 34                   Attention Required! | Cloudflare  Not Relevant
# 35                                   Home | Medtronic      Relevant
# 36  McKesson | Medical Supplies, Pharmaceuticals H...      Relevant
# 37  AmerisourceBergen | United in our responsibili...      Relevant
# 38                                                NaN           NaN
# 39             Medline.com | Medline Industries, Inc.      Relevant
#
#    Product Info Company Profile Partnerships Research & Innovations  \
# 0            No              No           No                     No
# 1            No              No           No                     No
# 2           Yes             Yes          Yes                    Yes
# 3           Yes             Yes          Yes                    Yes
# 4            No              No           No                     No
# 5           Yes             Yes          Yes                    Yes
# 6           Yes             Yes          Yes                    Yes
# 7            No              No           No                     No
# 8           Yes             Yes          Yes                     No
# 9           Yes             Yes          Yes                    Yes
# 10          NaN             NaN          NaN                    NaN
# 11          Yes             Yes          Yes                    Yes
# 12          Yes             Yes          Yes                    Yes
# 13          Yes             Yes          Yes                    Yes
# 14           No              No           No                     No
# 15          Yes             Yes          Yes                    Yes
# 16          Yes             Yes          Yes                    Yes
# 17          Yes             Yes          Yes                    Yes
# 18           No             Yes          Yes                     No
# 19           No              No           No                     No
# 20          Yes             Yes          Yes                    Yes
# 21           No              No           No                     No
# 22          Yes             Yes          Yes                    Yes
# 23           No              No           No                     No
# 24           No              No           No                     No
# 25          Yes             Yes          Yes                    Yes
# 26          Yes             Yes          Yes                    Yes
# 27           No              No           No                     No
# 28           No             Yes          Yes                     No
# 29           No              No           No                     No
# 30          Yes             Yes          Yes                    Yes
# 31          Yes              No           No                    Yes
# 32           No              No           No                     No
# 33           No              No           No                     No
# 34           No              No           No                     No
# 35          Yes             Yes          Yes                    Yes
# 36          Yes             Yes          Yes                    Yes
# 37          Yes             Yes          Yes                    Yes
# 38          NaN             NaN          NaN                    NaN
# 39          Yes              No           No                     No
#
#    Marketing & Promotions                                              Error
# 0                      No                                                NaN
# 1                      No                                                NaN
# 2                     Yes                                                NaN
# 3                      No                                                NaN
# 4                      No                                                NaN
# 5                     Yes                                                NaN
# 6                     Yes                                                NaN
# 7                      No                                                NaN
# 8                      No                                                NaN
# 9                     Yes                                                NaN
# 10                    NaN  HTTPSConnectionPool(host='www.kelloggs.com', p...
# 11                     No                                                NaN
# 12                     No                                                NaN
# 13                     No                                                NaN
# 14                     No                                                NaN
# 15                     No                                                NaN
# 16                     No                                                NaN
# 17                     No                                                NaN
# 18                     No                                                NaN
# 19                     No                                                NaN
# 20                    Yes                                                NaN
# 21                     No                                                NaN
# 22                    Yes                                                NaN
# 23                     No                                                NaN
# 24                     No                                                NaN
# 25                    Yes                                                NaN
# 26                    Yes                                                NaN
# 27                    Yes                                                NaN
# 28                     No                                                NaN
# 29                     No                                                NaN
# 30                     No                                                NaN
# 31                     No                                                NaN
# 32                     No                                                NaN
# 33                     No                                                NaN
# 34                     No                                                NaN
# 35                    Yes                                                NaN
# 36                    Yes                                                NaN
# 37                     No                                                NaN
# 38                    NaN  ('Connection aborted.', RemoteDisconnected('Re...
# 39                     No                                                NaN

# %%
df.head()
# Out:
#                     Company                           Website  \
# 0                    Nestle            https://www.nestle.com
# 1  Dr. Reddy's Laboratories          https://www.drreddys.com
# 2                 Coca-Cola  https://www.coca-colacompany.com
# 3                    Pfizer            https://www.pfizer.com
# 4                   PepsiCo           https://www.pepsico.com
#
#                                                Title      Category  \
# 0                                   Just a moment...  Not Relevant
# 1  Dr. Reddy’s Laboratories – Good Health Can’t Wait  Not Relevant
# 2  \n        The Coca-Cola Company: Refresh the W...      Relevant
# 3  Pfizer: One of the world's premier biopharmace...      Relevant
# 4                                           No Title  Not Relevant
#
#   Product Info Company Profile Partnerships Research & Innovations  \
# 0           No              No           No                     No
# 1           No              No           No                     No
# 2          Yes             Yes          Yes                    Yes
# 3          Yes             Yes          Yes                    Yes
# 4           No              No           No                     No
#
#   Marketing & Promotions Error
# 0                     No   NaN
# 1                     No   NaN
# 2                    Yes   NaN
# 3                     No   NaN
# 4                     No   NaN

# %%
df.tail()
# Out:
#                Company                                 Website  \
# 35           Medtronic               https://www.medtronic.com
# 36            McKesson                https://www.mckesson.com
# 37   AmerisourceBergen       https://www.amerisourcebergen.com
# 38     Cardinal Health  https://www.cardinalhealth.com/en.html
# 39  Medline Industries                 https://www.medline.com
#
#                                                 Title  Category Product Info  \
# 35                                   Home | Medtronic  Relevant          Yes
# 36  McKesson | Medical Supplies, Pharmaceuticals H...  Relevant          Yes
# 37  AmerisourceBergen | United in our responsibili...  Relevant          Yes
# 38                                                NaN       NaN          NaN
# 39             Medline.com | Medline Industries, Inc.  Relevant          Yes
#
#    Company Profile Partnerships Research & Innovations Marketing & Promotions  \
# 35             Yes          Yes                    Yes                    Yes
# 36             Yes          Yes                    Yes                    Yes
# 37             Yes          Yes                    Yes                     No
# 38             NaN          NaN                    NaN                    NaN
# 39              No           No                     No                     No
#
#                                                 Error
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  ('Connection aborted.', RemoteDisconnected('Re...
# 39                                                NaN

# %% [markdown]
# # Save results to an Excel file
#
# - Specified the full path for the output file below is the path

# %%
output_file = r"C:\Users\DELL\Music\Web Scraping F&B\company_analysis_extended.xlsx"

# %% [markdown]
# # Saved the DataFrame Final ouctome to the specified location

# %%
df.to_excel(output_file, index=False)

print(f"Analysis complete! Results saved to '{output_file}'")
# Out:
# Analysis complete! Results saved to 'C:\Users\DELL\Music\Web Scraping F&B\company_analysis_extended.xlsx'
